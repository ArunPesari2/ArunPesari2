# %% [markdown]
# <a href="https://colab.research.google.com/github/ArunPesari2/ArunPesari2/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#   Matplotlib is a comprehensive library for data Static data visualizations in Python
        #   pyplot,which is a subplot is a collection of functions that make matplotlib work like MATLAB, emulates matlab environment.
        #    Pyplot provides matplotlib with two key features:
                    #   A MATLAB-style interface, which allows those familiar with MATLAB to adopt Python more easily
                    #   Statefulness, which means that pyplot stores the state of an object when you first plot it. This is essential for use in the same loop or session state until plt.close() is encountered in the code. State can also be important when creating several plots continuously.  

#   seaborn is built on top of matplotlib(html+css) adds aestheic value 
#   plotly is like (JS), and interactive features, makes dynamic graphs used for presentation to the CEO's

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  # seaborn is based on matplotlib
import seaborn as sns   # Why sns?  It's a reference to The West Wing
sns.set(color_codes=True) # adds a nice background to the graphs
# %matplotlib inline 
# tells python to actually display the graphs

#   questions?
#   ==========
#   through using ONLY, matplotlib, could we interact with the graphs? IF yes, why we need plotly?
#   what is statefulness?

# %%
x=np.random.randn(100)
# normal distribuion
# x-axis past datapoints, like yesterday's temperature. relate to that example
# area under the curve is 1, which is nothing but the probability
# if we take any data point(, and took a st. line, the area of a st line is zero
# but we take
sns.distplot(x,hist=False);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# median
ages = np.arange(1,5)

y = pd.Series(ages).median()
print("median",y)
print()

print(pd.Series(ages).describe())
# Out:
# median 2.5
#
# count    4.000000
# mean     2.500000
# std      1.290994
# min      1.000000
# 25%      1.750000
# 50%      2.500000
# 75%      3.250000
# max      4.000000
# dtype: float64

# %%
# you could observe he y axis is not probability density but he count of the past data points
# just increasing bins
print(pd.Series(x).describe())
print("the median is",pd.Series(x).median())
# you could see the 50% is same as median(it happens when no. of elements are odd)


sns.distplot(x,kde=False, bins=20);
# Out:
# count    100.000000
# mean      -0.079167
# std        0.964637
# min       -2.871558
# 25%       -0.567685
# 50%       -0.179137
# 75%        0.676218
# max        2.570136
# dtype: float64
# the median is -0.17913651874857867
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# when we combine kde , histogram and rug plot we get the above but the y-axis for kde remains if there is kde
# as for histogram, we will just know just in which bin the counts are more, where as in rug plot we directly get 
# where see past data points

# if you combine all the three you will get more info
sns.distplot(x,rug=True,bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
# bivariate distribution
a=np.arange(-49,50)
x=-2*a*a+5*a
y=x*x-20*x-5
df=pd.concat([pd.Series(x),pd.Series(y)],axis=1)
#print(df)
sns.jointplot(data=df, x=x, y=y);

# %%
#x, yvectors or keys in data
#Variables that specify positions on the x and y axes.

#datapandas.DataFrame, numpy.ndarray, mapping, or sequence
#Input data structure. Either a long-form collection of vectors that can be assigned to named variables or a wide-form dataset that will be internally reshaped.

#kind{ “scatter” | “kde” | “hist” | “hex” | “reg” | “resid” }
#Kind of plot to draw. See the examples for references to the underlying functions.



sns.jointplot(data=df, x=x, y=y,kind="hex");
#you will acually get feel for the densiy

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-885222e5-a004-47b9-a9a3-9aa5ee1fba6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-885222e5-a004-47b9-a9a3-9aa5ee1fba6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Automobile.csv to Automobile.csv

# %%
import io
import pandas as pd
auto = pd.read_csv(io.BytesIO(uploaded['Automobile.csv']))

# %%
auto.head(10)
# Out:
#    symboling  normalized_losses         make  ... city_mpg highway_mpg  price
# 0          3                168  alfa-romero  ...       21          27  13495
# 1          3                168  alfa-romero  ...       21          27  16500
# 2          1                168  alfa-romero  ...       19          26  16500
# 3          2                164         audi  ...       24          30  13950
# 4          2                164         audi  ...       18          22  17450
# 5          2                161         audi  ...       19          25  15250
# 6          1                158         audi  ...       19          25  17710
# 7          1                168         audi  ...       19          25  18920
# 8          1                158         audi  ...       17          20  23875
# 9          2                192          bmw  ...       23          29  16430
#
# [10 rows x 26 columns]

# %% [markdown]
# ## Plotting univariate distributions
#
# The most convenient way to take a quick look at a univariate distribution in seaborn is the distplot() function. By default, this will draw a histogram and fit a kernel density estimate (KDE).

# %%
# to analyse one feature or a random variable, we use this handy tool
print(auto['highway_mpg'].describe())
sns.distplot(auto['highway_mpg']);
# Out:
# count    201.000000
# mean      30.686567
# std        6.815150
# min       16.000000
# 25%       25.000000
# 50%       30.000000
# 75%       34.000000
# max       54.000000
# Name: highway_mpg, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# we can turn the kde off and put a tic mark along the x-axis for every data point with rug
# iam here
sns.distplot(auto['city_mpg'], kde=False, rug=True);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Plotting bivariate distributions
#
# It can also be useful to visualize a relationship between two variables. The easiest way to do this in seaborn is to use the jointplot() function, which creates a scatterplot of the two variables along with the histograms of each next to the appropriate axes.

# %%
# questions
# what happens when there is null value in one of those series?
sns.jointplot(auto['engine_size'], auto['horsepower']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(auto['engine_size'], auto['horsepower']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Hex Bin Plots
#
# We can make a hex bin plot that breaks the 2D area into hexagons and the number of points in each hexagon determines the color

# %%
sns.jointplot(auto['engine_size'], auto['horsepower'], kind="hex");
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Kernel Density Estimation
#
# We can make a 2D estimation of the density also

# %%
# i did not get the kernel density estimation, correctly?
sns.jointplot(auto['engine_size'], auto['horsepower'], kind="kde");
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Visualizing pairwise relationships in a dataset
#
# To plot multiple pairwise scatterplots in a dataset, you can use the pairplot() function. This creates a matrix of axes and shows the relationship for each pair of columns in a DataFrame, it also draws the histogram of each variable on the diagonal Axes:
#
# Be careful about toggle scrolling in the cell menu!!!

# %%
# a dataframe is given as a parameter
sns.pairplot(auto[['normalized_losses', 'engine_size', 'horsepower']]);

# %% [markdown]
# ## Plotting with categorical data

# %% [markdown]
# In a strip plot, the scatterplot points will usually overlap. This makes it difficult to see the full distribution of data. One easy solution is to adjust the positions (only along the categorical axis) using “jitter"

# %%
# when you want to draw a scatter plot when one variable is categorical( then we use)
sns.stripplot(auto['fuel_type'], auto['horsepower'], jitter=True);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.stripplot(auto['horsepower'], auto['fuel_type'], jitter=True);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.stripplot(auto['horsepower'], auto['fuel_type'], jitter=False);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# A different approach would be to use the function swarmplot(), which positions each scatterplot point on the categorical axis and avoids overlapping points:

# %%
#   we could get each data points in a line of row even among those swap lines we could categorise/
sns.swarmplot(auto['fuel_type'], auto['horsepower']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Boxplots
#
# Another common graph is a boxplot(). This kind of plot shows the three quartile values of the distribution along with extreme values. The “whiskers” extend to points that lie within 1.5 IQRs of the lower and upper quartile, and then observations that fall outside this range are displayed independently.

# %%
# q2, median is the middle value, which is the line in the middle of the box
# q3, upper boundary of the box is the 3rd quartile 25% are above the value and 75% percent are below the value
# q1, lowest boundary of the box is the 1st  quartile 25% same goes for this.
# IQR, q1-q3, 25th to the 75th percentile.
# maximim whisker, Q3 + 1.5*IQR
# “minimum”: Q1 -1.5*IQR(it is thumb rule, that out side of this range is considered as outliers as statistics)
#
# Outside whiskers are outliers, which is shown with some dot 
# if there are no outliers in data set then the whisker is the maximum or minimum(below)
sns.boxplot(auto['number_of_doors'], auto['horsepower']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print(auto.shape)
sns.boxplot(auto['number_of_doors'], auto['horsepower'], hue=auto['fuel_type']);
# Out:
# (201, 26)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(auto['horsepower'],auto['number_of_doors'], hue=auto['fuel_type']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Bar plots
#
# We can plot the mean of a a dataset, separated in categories using the barplot() function. When there are multiple observations in each category, it uses bootstrapping to compute a confidence interval around the estimate and plots that using error bars:
#
# Bar plots start at 0, which can sometimes be practical if zero is a number you want to compare to

# %%
# question: HOW EXACTLY the confidence intervals are caluculated?
# what i understood is, if we do bootstrapping, (https://www.youtube.com/watch?v=655X9eZGxls)
#     95% of the time the means of the samples will be in this range.
      # question: how the bootstrapping takes place inside? what is the sample size to calculate the mean?

print(auto.groupby(['body_style','fuel_type'])['horsepower'].mean())
sns.barplot(auto['body_style'], auto['horsepower'], hue=auto['fuel_type']);
# Out:
# body_style   fuel_type
# convertible  gas          131.666667
# hardtop      diesel       123.000000
#              gas          145.000000
# hatchback    diesel        56.000000
#              gas           98.179104
# sedan        diesel        79.800000
#              gas          108.367089
# wagon        diesel       104.333333
#              gas           96.500000
# Name: horsepower, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
auto.groupby(['body_style','fuel_type']).count()
# Out:
#                        symboling  normalized_losses  ...  highway_mpg  price
# body_style  fuel_type                                ...
# convertible gas                6                  6  ...            6      6
# hardtop     diesel             1                  1  ...            1      1
#             gas                7                  7  ...            7      7
# hatchback   diesel             1                  1  ...            1      1
#             gas               67                 67  ...           67     67
# sedan       diesel            15                 15  ...           15     15
#             gas               79                 79  ...           79     79
# wagon       diesel             3                  3  ...            3      3
#             gas               22                 22  ...           22     22
#
# [9 rows x 24 columns]

# %% [markdown]
# A special case for the bar plot is when you want to show the number of observations in each category rather than computing the mean of a second variable. This is similar to a histogram over a categorical, rather than quantitative, variable. In seaborn, it’s easy to do so with the countplot() function:

# %%
sns.countplot(auto['body_style']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(auto['body_style'],hue=auto['fuel_type']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Point plots
#
# An alternative style for visualizing the same information is offered by the pointplot() function. This function also encodes the value of the estimate with height on the other axis, but rather than show a full bar it just plots the point estimate and confidence interval. Additionally, pointplot connects points from the same hue category. This makes it easy to see how the main relationship is changing as a function of a second variable, because your eyes are quite good at picking up on differences of slopes:

# %%
sns.pointplot(auto['body_style'], auto['horsepower'], hue=auto['number_of_doors']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Drawing multi-panel categorical plots

# %%
sns.catplot(x="fuel_type",
               y = "horsepower",
               hue="number_of_doors", 
               col="drive_wheels", 
               data=auto, 
               kind="box");

# %% [markdown]
# Various types of kind input : {``point``, ``bar``, ``count``, ``box``, ``violin``, ``strip``}

# %% [markdown]
# ## Function to draw linear regression models
#
# lmplot() is one of the most widely used function to quickly plot the Linear Relationship between 2 variables

# %%
sns.lmplot(y="horsepower", x="engine_size", data=auto);

# %%
sns.lmplot(y="horsepower", x="engine_size",hue="fuel_type", data=auto);
